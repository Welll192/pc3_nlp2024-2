# %% [markdown]
# Paso 1

# %%
# !pip install torch torchvision
# !pip install tqdm
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.6)

# %%
import os
import requests
import zipfile

# URL del archivo GloVe
glove_url = "http://nlp.stanford.edu/data/glove.6B.zip"
glove_zip_path = "glove.6B.zip"
glove_extract_path = "glove"

# Descarga el archivo zip de GloVe si no existe
if not os.path.exists(glove_zip_path):
    print("Descargando GloVe...")
    response = requests.get(glove_url, stream=True)
    with open(glove_zip_path, "wb") as f:
        for chunk in response.iter_content(chunk_size=1024):
            if chunk:
                f.write(chunk)

# Extrae el contenido del archivo zip
if not os.path.exists(glove_extract_path):
    print("Extrayendo GloVe...")
    with zipfile.ZipFile(glove_zip_path, "r") as zip_ref:
        zip_ref.extractall(glove_extract_path)

print("GloVe descargado y extraído correctamente.")
# Out:
# GloVe descargado y extraído correctamente.

# %% [markdown]
# Paso 2

# %%
import numpy as np

def load_embeddings(file_path):
    embeddings = {}
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            values = line.split()
            word = values[0]
            vector = np.array(values[1:], dtype='float32')
            embeddings[word] = vector
    return embeddings

# Carga de un archivo de embeddings
embedding_file = "glove/glove.6B.100d.txt"
concept_embeddings = load_embeddings(embedding_file)

# %% [markdown]
# Paso 3

# %%
def retrofit(embeddings, lexicon, alpha=0.5, iterations=10):
    retrofitted_embeddings = embeddings.copy()
    for _ in range(iterations):
        for word, neighbors in lexicon.items():
            if word not in embeddings:
                continue
            updated_vector = (alpha * embeddings[word])
            count = 0
            for neighbor in neighbors:
                if neighbor in embeddings:
                    updated_vector += ((1 - alpha) * embeddings[neighbor])
                    count += 1
            if count > 0:
                retrofitted_embeddings[word] = updated_vector / (count + alpha)
    return retrofitted_embeddings

# Ejemplo de léxico semántico
semantic_lexicon = {
    "person": ["human", "man", "woman", "boy", "girl", "child", "adult", "worker", "teacher", "student"],
    "city": ["metropolis", "town", "urban", "capital", "village", "borough", "municipality", "district", "region", "suburb"],
    "state": ["province", "region", "territory", "area", "zone", "division", "domain", "realm", "land", "nation"],
    "country": ["nation", "sovereign", "republic", "kingdom", "state", "land", "territory", "empire", "federation", "domain"],
    "organization": ["company", "corporation", "institution", "agency", "firm", "society", "association", "foundation", "enterprise", "business"],
    "animal": ["dog", "cat", "lion", "tiger", "elephant", "zebra", "giraffe", "horse", "cow", "sheep"],
    "vehicle": ["car", "truck", "bus", "bicycle", "motorcycle", "train", "airplane", "boat", "ship", "scooter"],
    "technology": ["computer", "internet", "software", "hardware", "mobile", "robot", "AI", "blockchain", "cloud", "server"],
    "emotion": ["happiness", "sadness", "anger", "fear", "love", "joy", "grief", "envy", "shame", "pride"],
    "food": ["bread", "milk", "cheese", "meat", "fish", "fruit", "vegetable", "rice", "pasta", "egg"],
    "color": ["red", "blue", "green", "yellow", "purple", "pink", "orange", "brown", "black", "white"],
    "weather": ["rain", "sun", "snow", "storm", "cloud", "wind", "fog", "hail", "thunder", "lightning"],
    "nature": ["tree", "flower", "river", "mountain", "ocean", "forest", "desert", "valley", "hill", "lake"],
    "sport": ["soccer", "basketball", "tennis", "golf", "cricket", "rugby", "swimming", "cycling", "running", "baseball"],
    "profession": ["doctor", "engineer", "nurse", "lawyer", "scientist", "artist", "musician", "actor", "chef", "writer"],
    "building": ["house", "apartment", "office", "school", "hospital", "store", "factory", "church", "museum", "library"],
    "tool": ["hammer", "wrench", "screwdriver", "drill", "saw", "shovel", "pliers", "knife", "axe", "ruler"],
    "science": ["physics", "chemistry", "biology", "mathematics", "astronomy", "geology", "genetics", "robotics", "ecology", "quantum"],
    "art": ["painting", "sculpture", "drawing", "photography", "dance", "theater", "film", "literature", "poetry", "design"],
    "body": ["head", "arm", "leg", "eye", "ear", "nose", "mouth", "hand", "foot", "chest"],
    "education": ["school", "college", "university", "class", "lecture", "teacher", "student", "exam", "degree", "homework"],
    "money": ["cash", "currency", "dollar", "euro", "yen", "coin", "bank", "credit", "account", "loan"],
    "time": ["minute", "hour", "day", "week", "month", "year", "decade", "century", "millennium", "moment"],
    "relation": ["family", "friend", "colleague", "partner", "enemy", "neighbor", "spouse", "child", "parent", "sibling"]
}

# Aplicar retrofitting
retrofitted_embeddings = retrofit(concept_embeddings, semantic_lexicon)

# %% [markdown]
# Paso 4

# %%
import pandas as pd

dataNER = pd.read_csv("dataNER.csv")

# %% [markdown]
# PREPROCESAMIENTO DE DATA

# %%
import re
import ast

# Función para limpiar las comillas dobles y convertir a listas reales
def clean_tags_column(tags_column):
    cleaned_tags = []
    for tag_entry in tags_column:
        if isinstance(tag_entry, str):
            cleaned_entry = re.sub(r"^\"|\]\"$", "", tag_entry)  # Eliminar comillas externas
            cleaned_entry = ast.literal_eval(cleaned_entry)  # Convertir la cadena a una lista real
            cleaned_tags.append(cleaned_entry)
        else:
            cleaned_tags.append(tag_entry)
    return cleaned_tags

dataNER["Tags"] = clean_tags_column(dataNER["Tags"])

dataNER["Tags"].tolist()
# Out:
# [['B-PER', 'O', 'O', 'O', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-PER', 'O', 'B-LOC'],
#  ['I-MISC', 'B-MISC', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-ORG', 'O', 'O', 'B-DATE'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-DATE', 'O', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-DATE', 'O', 'B-LOC', 'B-LOC'],
#  ['B-PER', 'O', 'I-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'B-MISC', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-DATE', 'B-LOC'],
#  ['B-PER', 'I-ORG', 'O', 'B-LOC'],
#  ['B-PER', 'B-PER', 'B-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-LOC', 'O', 'O', 'B-LOC'],
#  ['I-MISC', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-PER', 'B-LOC', 'I-PER'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-DATE', 'B-LOC', 'O', 'B-LOC', 'I-ORG'],
#  ['I-ORG', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-PROD'],
#  ['I-DATE', 'B-ORG', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-ORG'],
#  ['B-PER', 'O', 'B-PROD', 'I-MISC', 'I-LOC'],
#  ['B-PROD', 'B-DATE', 'O', 'I-PROD'],
#  ['I-DATE', 'B-PROD', 'I-ORG', 'I-DATE'],
#  ['B-PER', 'O', 'O', 'O'],
#  ['I-ORG', 'B-PROD', 'I-ORG', 'I-PER'],
#  ['B-PER', 'O', 'I-ORG', 'B-LOC'],
#  ['I-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-MISC', 'O', 'O', 'B-ORG', 'I-PROD'],
#  ['I-PROD', 'B-PROD', 'I-PER', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'I-PROD', 'O', 'B-LOC'],
#  ['O', 'O', 'O', 'I-MISC'],
#  ['I-LOC', 'I-MISC', 'O', 'B-LOC'],
#  ['B-MISC', 'O', 'I-MISC', 'B-LOC'],
#  ['B-PER', 'B-LOC', 'I-ORG', 'B-LOC'],
#  ['B-PER', 'B-ORG', 'B-LOC', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'I-LOC'],
#  ['B-PER', 'O', 'B-ORG', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-MISC'],
#  ['I-LOC', 'I-DATE', 'B-PROD', 'B-LOC'],
#  ['I-LOC', 'B-PER', 'O', 'B-PER', 'I-DATE'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-LOC', 'O', 'I-MISC', 'B-ORG'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-PER', 'O', 'I-DATE'],
#  ['B-PER', 'O', 'I-PROD', 'B-LOC'],
#  ['B-PER', 'I-PER', 'B-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-MISC', 'I-PROD', 'I-MISC'],
#  ['I-PROD', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-ORG', 'B-LOC'],
#  ['I-PROD', 'O', 'I-PER', 'B-LOC'],
#  ['I-PER', 'O', 'O', 'O', 'I-PROD'],
#  ['B-PER', 'O', 'B-DATE', 'O', 'B-DATE'],
#  ['B-MISC', 'I-ORG', 'O', 'B-PROD'],
#  ['I-PER', 'I-LOC', 'B-DATE', 'B-LOC'],
#  ['B-PER', 'I-MISC', 'B-MISC', 'B-LOC'],
#  ['B-PER', 'O', 'I-PER', 'B-DATE'],
#  ['B-PER', 'I-DATE', 'I-PER', 'B-LOC'],
#  ['B-PER', 'I-LOC', 'I-PER', 'B-PER'],
#  ['B-PER', 'O', 'O', 'O', 'B-ORG'],
#  ['B-MISC', 'B-ORG', 'B-PER', 'I-LOC'],
#  ['B-MISC', 'B-LOC', 'I-DATE', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'O', 'B-ORG', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'I-MISC', 'B-LOC'],
#  ['B-DATE', 'O', 'O', 'O', 'B-LOC'],
#  ['B-LOC', 'I-PER', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'I-MISC', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'B-ORG', 'I-DATE', 'I-LOC'],
#  ['B-ORG', 'O', 'O', 'O'],
#  ['B-PER', 'B-MISC', 'I-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-MISC', 'O', 'B-LOC', 'B-PROD'],
#  ['B-DATE', 'B-PER', 'O', 'B-DATE'],
#  ['B-PER', 'O', 'B-ORG', 'B-LOC', 'I-MISC'],
#  ['O', 'I-PER', 'O', 'B-MISC'],
#  ['I-ORG', 'O', 'O', 'O', 'I-PROD'],
#  ['B-PER', 'O', 'I-LOC', 'B-LOC'],
#  ['B-PROD', 'O', 'I-ORG', 'I-MISC'],
#  ['I-PER', 'O', 'O', 'O', 'I-ORG'],
#  ['B-PER', 'B-PER', 'B-LOC', 'B-PER'],
#  ['O', 'B-PER', 'O', 'O'],
#  ['B-PER', 'O', 'I-PER', 'I-PER'],
#  ['B-PER', 'I-DATE', 'O', 'I-PER'],
#  ['B-ORG', 'O', 'O', 'B-LOC'],
#  ['I-PROD', 'I-PROD', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-PROD'],
#  ['B-PER', 'O', 'I-PER', 'I-ORG'],
#  ['O', 'O', 'O', 'B-PROD'],
#  ['I-PER', 'I-DATE', 'O', 'I-MISC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PROD', 'O', 'I-LOC', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-LOC', 'O', 'I-DATE', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-DATE', 'B-PER', 'O', 'B-PER', 'I-LOC'],
#  ['B-MISC', 'I-PROD', 'O', 'B-LOC'],
#  ['B-PER', 'I-LOC', 'B-PER', 'B-LOC'],
#  ['B-PER', 'I-LOC', 'B-ORG', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-MISC', 'O', 'B-ORG'],
#  ['I-ORG', 'O', 'O', 'I-PER'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'B-DATE', 'I-PROD'],
#  ['B-PER', 'O', 'I-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'B-MISC', 'B-LOC'],
#  ['I-PER', 'O', 'O', 'I-DATE', 'B-LOC'],
#  ['B-DATE', 'O', 'I-ORG', 'B-DATE'],
#  ['B-ORG', 'B-PER', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-LOC', 'I-ORG', 'O', 'B-ORG'],
#  ['B-PER', 'B-DATE', 'O', 'B-PER'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-ORG', 'I-LOC', 'B-ORG', 'I-LOC'],
#  ['B-PER', 'I-PER', 'O', 'B-LOC'],
#  ['I-DATE', 'B-MISC', 'I-PROD', 'I-ORG'],
#  ['I-PER', 'O', 'B-PER', 'I-ORG'],
#  ['B-LOC', 'B-ORG', 'O', 'I-PER'],
#  ['B-PER', 'B-LOC', 'O', 'B-MISC'],
#  ['B-PER', 'O', 'O', 'I-PROD'],
#  ['B-PER', 'I-PROD', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-PROD', 'B-PER', 'O', 'I-LOC', 'O'],
#  ['B-PER', 'B-PROD', 'O', 'B-PER', 'B-ORG'],
#  ['I-PER', 'B-PER', 'B-ORG', 'B-LOC'],
#  ['B-PER', 'I-ORG', 'B-PROD', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'I-PROD'],
#  ['B-MISC', 'B-ORG', 'O', 'B-LOC'],
#  ['I-PER', 'O', 'O', 'O', 'I-PER'],
#  ['O', 'O', 'O', 'B-LOC'],
#  ['I-LOC', 'B-LOC', 'I-MISC', 'B-LOC'],
#  ['B-ORG', 'O', 'B-ORG', 'B-PROD'],
#  ['I-PER', 'O', 'B-PER', 'B-LOC'],
#  ['B-LOC', 'O', 'I-DATE', 'I-DATE'],
#  ['B-PER', 'I-DATE', 'B-PER', 'B-LOC', 'I-LOC'],
#  ['I-DATE', 'O', 'B-ORG', 'B-LOC'],
#  ['B-PER', 'B-LOC', 'B-MISC', 'O'],
#  ['B-PER', 'O', 'O', 'I-DATE', 'B-PROD'],
#  ['B-MISC', 'B-MISC', 'I-LOC', 'I-LOC'],
#  ['B-PER', 'O', 'B-PROD', 'B-LOC'],
#  ['I-MISC', 'B-LOC', 'O', 'I-MISC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-PROD', 'I-ORG'],
#  ['B-PER', 'B-LOC', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-PROD'],
#  ['B-PER', 'B-DATE', 'O', 'B-DATE'],
#  ['B-PER', 'O', 'I-MISC', 'B-LOC'],
#  ['O', 'O', 'B-DATE', 'B-LOC', 'O'],
#  ['B-PER', 'O', 'I-ORG', 'B-LOC'],
#  ['B-PER', 'B-PROD', 'B-PROD', 'B-LOC'],
#  ['I-PROD', 'O', 'B-MISC', 'I-DATE'],
#  ['B-PER', 'I-DATE', 'O', 'I-DATE', 'B-MISC'],
#  ['B-MISC', 'I-MISC', 'I-LOC', 'B-MISC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-ORG', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'I-DATE', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'I-MISC', 'B-PER', 'B-PER'],
#  ['I-DATE', 'O', 'O', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-LOC', 'O', 'I-PROD'],
#  ['B-PER', 'B-PER', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-DATE', 'O', 'O', 'B-LOC'],
#  ['I-MISC', 'B-ORG', 'O', 'B-PER', 'I-LOC'],
#  ['B-PER', 'O', 'B-MISC', 'B-ORG', 'I-PER'],
#  ['I-ORG', 'O', 'I-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'B-DATE', 'B-LOC'],
#  ['I-DATE', 'O', 'B-PER', 'B-LOC'],
#  ['B-PER', 'O', 'B-DATE', 'I-LOC', 'I-LOC'],
#  ['I-ORG', 'O', 'O', 'I-PER'],
#  ['I-DATE', 'O', 'O', 'I-PROD', 'I-LOC'],
#  ['B-PER', 'O', 'I-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-PER', 'B-ORG', 'O', 'B-PER'],
#  ['B-PER', 'O', 'B-ORG', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-ORG', 'B-ORG', 'O', 'B-LOC'],
#  ['I-LOC', 'I-LOC', 'I-LOC', 'I-ORG'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'O', 'B-LOC'],
#  ['I-LOC', 'O', 'O', 'O', 'B-MISC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-PER', 'I-ORG', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-MISC', 'B-DATE', 'B-DATE', 'I-DATE'],
#  ['B-PER', 'I-PROD', 'B-PER', 'B-LOC'],
#  ['B-PER', 'O', 'I-MISC', 'B-LOC', 'I-ORG'],
#  ['B-PER', 'I-ORG', 'I-PROD', 'I-MISC', 'O'],
#  ['B-PER', 'B-DATE', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'I-ORG', 'I-PER'],
#  ['B-PROD', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'I-PER', 'I-LOC'],
#  ['B-PER', 'B-LOC', 'O', 'O'],
#  ['B-PER', 'O', 'I-LOC', 'B-LOC', 'B-PER'],
#  ['B-PER', 'O', 'O', 'I-ORG', 'I-LOC'],
#  ['B-MISC', 'O', 'B-PER', 'B-LOC'],
#  ['B-PER', 'I-DATE', 'O', 'I-PER'],
#  ['B-MISC', 'O', 'B-LOC', 'B-LOC'],
#  ['B-PER', 'B-LOC', 'B-ORG', 'B-LOC'],
#  ['B-PER', 'I-PER', 'I-MISC', 'I-ORG', 'I-PROD'],
#  ['B-PER', 'O', 'O', 'I-PROD'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['O', 'O', 'O', 'B-LOC'],
#  ['I-ORG', 'I-PER', 'O', 'B-LOC'],
#  ['B-PER', 'B-DATE', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-ORG', 'B-PER'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'B-DATE', 'B-LOC'],
#  ['B-LOC', 'I-MISC', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-PER'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-DATE', 'B-LOC', 'B-ORG', 'O'],
#  ['B-PER', 'I-ORG', 'O', 'I-MISC'],
#  ['B-PER', 'I-LOC', 'O', 'I-ORG'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'B-DATE', 'B-PROD'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-ORG', 'B-PER', 'I-ORG'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-MISC', 'O'],
#  ['B-PER', 'I-PROD', 'O', 'I-PROD'],
#  ['B-LOC', 'O', 'I-DATE', 'B-LOC'],
#  ['B-PER', 'I-LOC', 'I-ORG', 'B-DATE', 'I-LOC'],
#  ['B-ORG', 'O', 'I-MISC', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['O', 'O', 'O', 'B-LOC'],
#  ['I-ORG', 'O', 'O', 'B-ORG'],
#  ['I-ORG', 'I-ORG', 'O', 'B-PROD'],
#  ['I-MISC', 'O', 'I-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-PER'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'I-LOC', 'I-PROD'],
#  ['B-PER', 'B-ORG', 'O', 'B-PROD', 'B-DATE'],
#  ['I-MISC', 'I-MISC', 'O', 'B-LOC'],
#  ['I-MISC', 'O', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-LOC', 'I-LOC', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-PROD', 'B-ORG'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-DATE', 'O', 'O', 'B-LOC'],
#  ['I-MISC', 'O', 'O', 'B-ORG'],
#  ['B-DATE', 'O', 'I-DATE', 'B-LOC'],
#  ['B-PER', 'I-PER', 'O', 'B-LOC', 'B-DATE'],
#  ['B-PER', 'B-PROD', 'B-ORG', 'B-LOC'],
#  ['I-MISC', 'I-PER', 'B-PROD', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-PROD', 'B-MISC', 'O', 'I-PROD'],
#  ['B-PER', 'B-LOC', 'I-ORG', 'B-DATE'],
#  ['B-PER', 'I-PROD', 'I-PROD', 'B-LOC'],
#  ['I-LOC', 'I-PER', 'B-MISC', 'B-LOC'],
#  ['B-MISC', 'I-ORG', 'O', 'B-PER'],
#  ['B-PER', 'B-ORG', 'I-LOC', 'B-LOC'],
#  ['B-PER', 'O', 'B-PROD', 'B-LOC'],
#  ['B-LOC', 'I-LOC', 'O', 'I-ORG'],
#  ['B-MISC', 'B-DATE', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-DATE', 'B-LOC', 'B-DATE'],
#  ['I-MISC', 'O', 'O', 'B-MISC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-DATE', 'O'],
#  ['I-PROD', 'O', 'O', 'I-PROD'],
#  ['O', 'B-ORG', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'I-MISC', 'I-ORG'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-DATE', 'O', 'I-ORG', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-MISC'],
#  ['O', 'O', 'I-PROD', 'I-LOC'],
#  ['B-PER', 'B-LOC', 'I-LOC', 'I-DATE'],
#  ['I-LOC', 'B-PER', 'I-PROD', 'B-MISC'],
#  ['B-PER', 'O', 'B-DATE', 'I-ORG'],
#  ['B-MISC', 'O', 'O', 'B-LOC'],
#  ['I-ORG', 'B-PER', 'O', 'I-DATE'],
#  ['B-PER', 'B-DATE', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'B-ORG', 'B-LOC'],
#  ['I-DATE', 'O', 'O', 'I-ORG'],
#  ['B-PER', 'B-LOC', 'B-PROD', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC', 'I-LOC'],
#  ['I-PER', 'O', 'O', 'B-LOC', 'B-PER'],
#  ['B-DATE', 'I-DATE', 'O', 'I-ORG'],
#  ['B-PROD', 'O', 'O', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'B-MISC', 'B-PER', 'I-ORG', 'I-LOC'],
#  ['B-PER', 'O', 'B-DATE', 'I-ORG'],
#  ['B-PER', 'B-MISC', 'O', 'B-MISC'],
#  ['I-ORG', 'O', 'O', 'I-PER'],
#  ['B-PER', 'I-LOC', 'B-DATE', 'O'],
#  ['B-PER', 'B-MISC', 'O', 'B-PROD', 'I-LOC'],
#  ['O', 'O', 'B-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-PROD'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-PROD'],
#  ['I-PROD', 'O', 'O', 'O', 'I-PER'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-PER', 'B-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-LOC', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-PER', 'O', 'B-LOC', 'B-DATE'],
#  ['I-LOC', 'I-ORG', 'O', 'B-LOC'],
#  ['I-PER', 'O', 'I-MISC', 'I-ORG'],
#  ['B-PER', 'O', 'O', 'O', 'B-ORG'],
#  ['B-LOC', 'B-DATE', 'B-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'I-DATE', 'B-PER', 'B-PROD'],
#  ['B-PER', 'O', 'O', 'B-ORG'],
#  ['B-PER', 'O', 'O', 'B-ORG'],
#  ['B-PER', 'I-MISC', 'O', 'B-PROD'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-ORG', 'O', 'B-PER'],
#  ['B-MISC', 'O', 'I-LOC', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-PROD'],
#  ['B-PER', 'I-DATE', 'O', 'O'],
#  ['I-LOC', 'I-ORG', 'O', 'I-ORG', 'B-PROD'],
#  ['O', 'O', 'I-PROD', 'B-LOC'],
#  ['O', 'B-LOC', 'O', 'I-ORG'],
#  ['I-PROD', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PROD', 'B-MISC', 'O', 'B-LOC'],
#  ['B-ORG', 'B-PROD', 'O', 'I-DATE'],
#  ['B-PROD', 'O', 'O', 'O', 'B-DATE'],
#  ['B-PER', 'O', 'B-MISC', 'B-LOC', 'I-LOC'],
#  ['I-LOC', 'I-PER', 'B-LOC', 'B-ORG', 'I-LOC'],
#  ['B-MISC', 'O', 'I-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'O', 'I-PROD', 'B-MISC'],
#  ['I-LOC', 'B-ORG', 'I-PROD', 'B-LOC'],
#  ['B-PER', 'I-ORG', 'I-PER', 'I-PROD'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['I-ORG', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'O'],
#  ['B-DATE', 'O', 'B-PER', 'B-LOC'],
#  ['B-PER', 'O', 'B-PER', 'B-LOC'],
#  ['B-PER', 'I-DATE', 'O', 'B-MISC', 'I-LOC'],
#  ['B-PER', 'B-PER', 'O', 'B-LOC'],
#  ['I-MISC', 'O', 'I-DATE', 'B-LOC'],
#  ['B-PER', 'B-ORG', 'B-PROD', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['I-LOC', 'I-PROD', 'B-LOC', 'B-LOC'],
#  ['B-PER', 'B-PROD', 'O', 'B-LOC'],
#  ['B-PER', 'I-LOC', 'O', 'B-ORG'],
#  ['B-PER', 'O', 'O', 'B-MISC'],
#  ['B-PER', 'B-DATE', 'O', 'B-PER'],
#  ['B-PER', 'B-PER', 'I-MISC', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-MISC', 'O', 'B-LOC'],
#  ['I-DATE', 'I-DATE', 'I-MISC', 'I-DATE'],
#  ['B-PER', 'B-PER', 'I-MISC', 'B-ORG'],
#  ['O', 'O', 'O', 'B-LOC'],
#  ['B-MISC', 'I-MISC', 'B-MISC', 'B-LOC'],
#  ['I-DATE', 'O', 'I-ORG', 'B-PER'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-MISC', 'B-MISC', 'B-MISC'],
#  ['I-DATE', 'I-PROD', 'B-PROD', 'B-LOC'],
#  ['B-PER', 'O', 'B-ORG', 'B-LOC'],
#  ['I-LOC', 'O', 'O', 'I-DATE'],
#  ['B-MISC', 'O', 'O', 'I-MISC'],
#  ['B-LOC', 'I-PROD', 'O', 'B-DATE'],
#  ['B-PER', 'O', 'O', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'O', 'B-PROD', 'B-PER'],
#  ['O', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-LOC', 'O', 'O'],
#  ['B-PER', 'O', 'O', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-DATE', 'B-MISC', 'B-DATE'],
#  ['B-ORG', 'B-LOC', 'O', 'I-PROD'],
#  ['I-DATE', 'O', 'O', 'I-DATE'],
#  ['B-PER', 'B-PER', 'B-MISC', 'B-LOC'],
#  ['B-PROD', 'I-MISC', 'B-PROD', 'B-PER'],
#  ['B-PER', 'I-DATE', 'O', 'B-LOC'],
#  ['I-PROD', 'B-MISC', 'O', 'I-PROD'],
#  ['B-PER', 'O', 'I-PROD', 'B-LOC'],
#  ['B-PROD', 'I-DATE', 'B-PROD', 'B-PROD'],
#  ['B-MISC', 'O', 'O', 'I-LOC', 'B-ORG'],
#  ['B-PROD', 'B-DATE', 'O', 'B-PER'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-ORG', 'I-ORG', 'O', 'B-PROD'],
#  ['I-PER', 'O', 'B-PER', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-PROD', 'B-PROD'],
#  ['B-PER', 'I-DATE', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-DATE', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-MISC', 'B-LOC', 'B-LOC'],
#  ['I-MISC', 'O', 'O', 'I-LOC', 'B-LOC'],
#  ['B-MISC', 'I-DATE', 'B-ORG', 'B-PROD'],
#  ['I-MISC', 'O', 'O', 'I-PER'],
#  ['B-PER', 'I-ORG', 'I-PER', 'I-ORG'],
#  ['B-LOC', 'O', 'O', 'I-PER'],
#  ['B-MISC', 'I-MISC', 'I-PER', 'B-ORG'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-PROD', 'B-DATE', 'B-LOC'],
#  ['B-PER', 'B-ORG', 'B-PER', 'B-LOC', 'B-PROD'],
#  ['B-MISC', 'I-PROD', 'O', 'B-PER'],
#  ['B-ORG', 'O', 'B-PER', 'O'],
#  ['B-DATE', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-PER', 'O', 'B-LOC', 'O'],
#  ['B-PER', 'I-DATE', 'I-PROD', 'B-LOC', 'B-PROD'],
#  ['I-DATE', 'O', 'B-ORG', 'B-LOC'],
#  ['B-PER', 'I-PER', 'O', 'I-PROD'],
#  ['B-MISC', 'I-DATE', 'B-ORG', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-DATE', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-PER', 'B-LOC', 'O'],
#  ['I-ORG', 'B-ORG', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-LOC', 'I-MISC', 'O', 'B-ORG'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-LOC', 'O', 'I-LOC', 'B-MISC'],
#  ['I-PER', 'B-PROD', 'O', 'B-LOC'],
#  ['I-LOC', 'B-ORG', 'O', 'B-LOC'],
#  ['B-LOC', 'O', 'O', 'I-MISC'],
#  ['B-PER', 'O', 'O', 'B-DATE'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'I-ORG', 'O'],
#  ['O', 'O', 'I-DATE', 'B-LOC'],
#  ['B-PER', 'B-LOC', 'B-LOC', 'B-LOC'],
#  ['B-PER', 'B-PER', 'B-ORG', 'B-PROD'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-PER', 'I-LOC', 'B-MISC', 'B-LOC'],
#  ['B-PER', 'I-PER', 'I-PROD', 'B-LOC'],
#  ['I-LOC', 'O', 'O', 'O', 'I-PROD'],
#  ['B-DATE', 'B-MISC', 'O', 'B-PER'],
#  ['B-DATE', 'B-ORG', 'I-PROD', 'B-LOC'],
#  ['B-PER', 'I-DATE', 'O', 'I-ORG'],
#  ['B-PER', 'B-ORG', 'O', 'B-LOC'],
#  ['I-DATE', 'O', 'B-PER', 'B-LOC', 'I-LOC'],
#  ['B-LOC', 'O', 'O', 'O', 'B-LOC'],
#  ['I-ORG', 'B-MISC', 'O', 'B-PROD'],
#  ['B-PER', 'I-DATE', 'O', 'B-LOC'],
#  ['B-PER', 'I-LOC', 'O', 'I-DATE'],
#  ['I-DATE', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-LOC', 'I-LOC', 'O', 'B-LOC'],
#  ['B-PER', 'B-PROD', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'I-PROD', 'B-DATE'],
#  ['B-PER', 'B-MISC', 'I-LOC', 'B-MISC', 'I-PROD'],
#  ['B-PER', 'O', 'O', 'I-PER'],
#  ['B-PER', 'B-DATE', 'B-PER', 'B-LOC'],
#  ['B-PER', 'B-PER', 'B-DATE', 'I-PER', 'B-PROD'],
#  ['B-LOC', 'O', 'I-PER', 'I-DATE'],
#  ['I-LOC', 'O', 'O', 'O', 'B-MISC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-MISC', 'B-PROD', 'B-LOC'],
#  ['B-LOC', 'B-DATE', 'O', 'B-LOC'],
#  ['B-PER', 'B-PROD', 'I-ORG', 'I-LOC'],
#  ['I-MISC', 'O', 'O', 'I-PROD'],
#  ['I-DATE', 'I-ORG', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-LOC', 'O', 'B-DATE', 'B-LOC'],
#  ['I-PER', 'B-ORG', 'B-DATE', 'B-LOC', 'I-LOC'],
#  ['I-DATE', 'O', 'B-ORG', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-MISC'],
#  ['B-PER', 'B-LOC', 'O', 'B-ORG'],
#  ['B-PER', 'I-MISC', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'I-DATE', 'O'],
#  ['B-PROD', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-DATE', 'O', 'B-LOC'],
#  ['B-MISC', 'B-PROD', 'I-DATE', 'B-DATE'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-LOC', 'O', 'I-ORG', 'B-LOC'],
#  ['B-DATE', 'B-MISC', 'O', 'B-LOC'],
#  ['B-PER', 'B-MISC', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'O', 'I-PER', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-PROD', 'O', 'O', 'B-ORG'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-ORG', 'I-MISC', 'B-PER'],
#  ['B-ORG', 'O', 'B-PROD', 'I-MISC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['I-PROD', 'O', 'O', 'O', 'B-MISC', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-ORG', 'O', 'B-LOC'],
#  ['B-PER', 'B-PROD', 'B-PROD', 'B-LOC', 'I-LOC'],
#  ['B-DATE', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-ORG', 'I-PROD', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-LOC', 'I-PROD', 'B-MISC', 'I-DATE'],
#  ['I-ORG', 'I-DATE', 'O', 'B-LOC'],
#  ['B-PROD', 'B-LOC', 'O', 'B-PROD', 'B-PROD'],
#  ['I-PROD', 'B-PROD', 'O', 'B-LOC'],
#  ['I-PROD', 'B-PER', 'I-ORG', 'B-ORG'],
#  ['B-DATE', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'B-DATE'],
#  ['B-PER', 'I-PROD', 'I-PER', 'I-ORG'],
#  ['B-PER', 'I-DATE', 'O', 'B-LOC', 'I-LOC'],
#  ['B-MISC', 'I-ORG', 'O', 'B-ORG', 'O'],
#  ['B-PER', 'I-PROD', 'O', 'I-DATE'],
#  ['I-PER', 'B-DATE', 'B-LOC', 'B-LOC'],
#  ['B-PER', 'B-ORG', 'O', 'I-PER'],
#  ['I-DATE', 'O', 'O', 'B-LOC', 'I-PROD'],
#  ['B-PROD', 'O', 'O', 'B-PROD'],
#  ['B-DATE', 'B-DATE', 'O', 'B-LOC'],
#  ['B-PER', 'I-DATE', 'B-DATE', 'B-LOC'],
#  ['I-LOC', 'O', 'I-PROD', 'B-PER'],
#  ['I-PROD', 'I-PROD', 'B-LOC', 'B-DATE'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'B-PROD', 'I-DATE'],
#  ['B-PER', 'O', 'B-MISC', 'I-DATE'],
#  ['I-PROD', 'B-MISC', 'B-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-DATE', 'B-MISC', 'O'],
#  ['B-MISC', 'O', 'O', 'B-MISC'],
#  ['B-PER', 'B-PER', 'B-DATE', 'B-DATE'],
#  ['B-LOC', 'I-PROD', 'O', 'B-LOC'],
#  ['B-PER', 'I-ORG', 'I-ORG', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'I-ORG', 'B-LOC'],
#  ['B-MISC', 'I-DATE', 'I-PER', 'I-MISC'],
#  ['B-PER', 'I-MISC', 'O', 'B-PER'],
#  ['B-ORG', 'B-ORG', 'B-DATE', 'B-PER'],
#  ['I-PER', 'I-DATE', 'O', 'B-LOC'],
#  ['B-PER', 'B-MISC', 'B-MISC', 'B-LOC'],
#  ['B-DATE', 'B-PROD', 'O', 'B-LOC'],
#  ['B-PER', 'B-DATE', 'O', 'B-LOC'],
#  ['B-PER', 'B-LOC', 'O', 'B-LOC'],
#  ['B-PER', 'I-MISC', 'O', 'B-DATE', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-PROD', 'B-MISC', 'B-DATE', 'B-PROD'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-PROD', 'O', 'O', 'O', 'B-ORG'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-LOC', 'I-LOC', 'B-LOC', 'I-MISC'],
#  ['B-PER', 'O', 'O', 'I-LOC'],
#  ['B-PER', 'I-DATE', 'B-PER', 'B-LOC'],
#  ['B-PROD', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-ORG', 'O', 'I-PER'],
#  ['B-PER', 'O', 'I-DATE', 'I-PROD'],
#  ['B-PER', 'O', 'O', 'I-ORG'],
#  ['B-PER', 'B-LOC', 'O', 'B-LOC'],
#  ['B-PER', 'I-DATE', 'O', 'I-MISC'],
#  ['B-PER', 'O', 'O', 'B-ORG', 'O'],
#  ['B-LOC', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-DATE', 'I-ORG', 'B-LOC'],
#  ['B-PER', 'O', 'B-MISC', 'I-PER'],
#  ['B-PER', 'B-PROD', 'B-ORG', 'B-LOC'],
#  ['B-DATE', 'B-MISC', 'O', 'B-LOC'],
#  ['I-LOC', 'O', 'I-PROD', 'B-PER'],
#  ['B-PER', 'I-PROD', 'O', 'B-LOC', 'B-LOC'],
#  ['I-PROD', 'I-ORG', 'O', 'B-ORG'],
#  ['B-PER', 'O', 'O', 'O'],
#  ['B-PER', 'O', 'O', 'I-DATE'],
#  ['B-PER', 'I-DATE', 'O', 'I-LOC'],
#  ['I-MISC', 'O', 'O', 'B-LOC'],
#  ['I-PROD', 'O', 'O', 'B-PER', 'B-DATE', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['I-PROD', 'O', 'B-DATE', 'B-LOC'],
#  ['I-MISC', 'B-PROD', 'O', 'B-LOC'],
#  ['I-PROD', 'O', 'O', 'O', 'B-LOC'],
#  ['I-LOC', 'O', 'I-DATE', 'B-LOC'],
#  ['I-MISC', 'I-PROD', 'O', 'B-DATE'],
#  ['I-MISC', 'O', 'O', 'B-ORG', 'I-LOC'],
#  ['B-PER', 'O', 'B-DATE', 'I-MISC'],
#  ['B-PER', 'O', 'B-LOC', 'B-PER'],
#  ['I-DATE', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-LOC', 'O', 'B-LOC'],
#  ['B-PER', 'I-PROD', 'B-LOC', 'B-DATE'],
#  ['I-PROD', 'O', 'O', 'B-LOC'],
#  ['I-MISC', 'O', 'B-PER', 'B-LOC'],
#  ['I-MISC', 'O', 'I-PROD', 'I-ORG'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-MISC', 'B-LOC'],
#  ['I-DATE', 'B-DATE', 'O', 'I-LOC'],
#  ['B-PER', 'B-DATE', 'B-PER', 'B-LOC'],
#  ['B-DATE', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-ORG', 'B-PROD', 'I-DATE', 'I-DATE'],
#  ['I-DATE', 'B-DATE', 'O', 'O'],
#  ['I-PER', 'I-PROD', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'I-LOC', 'I-LOC'],
#  ['B-PROD', 'I-DATE', 'O', 'B-PER'],
#  ['B-PER', 'O', 'B-ORG', 'I-DATE'],
#  ['B-PER', 'B-PER', 'O', 'B-PROD'],
#  ['B-PER', 'O', 'O', 'B-DATE'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-LOC', 'O', 'B-LOC'],
#  ['B-PER', 'B-PROD', 'I-DATE', 'I-ORG'],
#  ['B-PER', 'O', 'I-ORG', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-ORG', 'I-PER'],
#  ['O', 'B-PROD', 'O', 'B-LOC', 'B-MISC'],
#  ['B-PER', 'O', 'O', 'O', 'B-ORG', 'I-LOC'],
#  ['B-PER', 'O', 'B-PER', 'I-PROD'],
#  ['B-PROD', 'O', 'B-PROD', 'B-LOC'],
#  ['B-DATE', 'B-PER', 'O', 'I-ORG'],
#  ['B-PER', 'O', 'O', 'I-ORG'],
#  ['B-ORG', 'O', 'O', 'I-PROD'],
#  ['B-PER', 'B-LOC', 'O', 'B-LOC'],
#  ['B-DATE', 'I-PER', 'I-ORG', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-LOC', 'I-LOC', 'O', 'B-LOC'],
#  ['I-PROD', 'B-DATE', 'B-PROD', 'B-PER'],
#  ['B-PER', 'I-ORG', 'B-MISC', 'B-LOC', 'B-MISC'],
#  ['B-PER', 'O', 'B-PER', 'I-ORG'],
#  ['B-DATE', 'I-PROD', 'B-PROD', 'I-LOC'],
#  ['B-PER', 'I-PER', 'I-MISC', 'I-DATE'],
#  ['B-PER', 'I-PER', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-PER', 'O', 'B-LOC'],
#  ['I-PROD', 'O', 'O', 'O', 'B-LOC'],
#  ['I-ORG', 'I-PER', 'I-LOC', 'B-LOC'],
#  ['B-PER', 'I-ORG', 'O', 'B-LOC'],
#  ['B-MISC', 'B-LOC', 'I-ORG', 'B-LOC', 'B-PER'],
#  ['I-PROD', 'O', 'O', 'B-PROD'],
#  ['B-LOC', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-LOC'],
#  ['B-MISC', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'B-ORG', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-PROD', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-LOC'],
#  ['B-ORG', 'B-LOC', 'B-DATE', 'I-PER'],
#  ['I-PROD', 'O', 'O', 'B-PROD', 'I-ORG'],
#  ['B-PER', 'B-MISC', 'I-LOC', 'O'],
#  ['B-PER', 'O', 'O', 'B-PER', 'B-PROD', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-MISC', 'I-PROD', 'O', 'B-LOC'],
#  ['B-PER', 'B-PROD', 'O', 'B-ORG'],
#  ['B-ORG', 'O', 'O', 'B-PER', 'I-LOC'],
#  ['O', 'I-MISC', 'O', 'B-LOC'],
#  ['I-ORG', 'I-LOC', 'O', 'I-PER'],
#  ['I-MISC', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-ORG', 'O', 'O', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-LOC'],
#  ['B-PER', 'I-PROD', 'B-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-MISC', 'O', 'I-DATE', 'B-MISC'],
#  ['B-DATE', 'I-MISC', 'O', 'B-PROD'],
#  ['B-PER', 'O', 'O', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-ORG', 'I-PER', 'I-DATE', 'B-LOC'],
#  ['B-PER', 'I-DATE', 'O', 'I-PER'],
#  ['I-PROD', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-DATE', 'O', 'I-DATE'],
#  ['B-PER', 'O', 'B-PER', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-DATE'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'B-ORG', 'B-LOC'],
#  ['I-PROD', 'B-MISC', 'I-MISC', 'O'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-PROD', 'I-DATE', 'I-PROD', 'B-LOC'],
#  ['B-PER', 'B-PER', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-MISC', 'B-MISC', 'B-PER'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-PROD', 'O', 'B-LOC'],
#  ['B-PER', 'I-LOC', 'B-ORG', 'I-DATE'],
#  ['I-MISC', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'I-LOC', 'O', 'B-ORG'],
#  ['I-PROD', 'B-PER', 'O', 'B-LOC'],
#  ['I-DATE', 'I-LOC', 'I-MISC', 'O', 'I-LOC'],
#  ['B-DATE', 'O', 'O', 'O', 'B-PER'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['I-ORG', 'I-LOC', 'O', 'I-PER'],
#  ['B-PER', 'I-PER', 'O', 'I-PROD'],
#  ['B-PER', 'O', 'O', 'B-MISC'],
#  ['B-PER', 'I-PER', 'O', 'O'],
#  ['B-PER', 'I-ORG', 'I-MISC', 'B-LOC', 'I-LOC'],
#  ['B-ORG', 'I-ORG', 'O', 'I-PROD'],
#  ['B-MISC', 'O', 'O', 'I-DATE'],
#  ['I-ORG', 'O', 'I-PROD', 'B-LOC'],
#  ['B-PER', 'B-PROD', 'O', 'B-LOC', 'I-MISC'],
#  ['B-PER', 'O', 'B-ORG', 'B-LOC', 'B-MISC'],
#  ['B-ORG', 'O', 'I-ORG', 'B-ORG'],
#  ['B-PER', 'O', 'B-LOC', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'O', 'O', 'B-LOC', 'I-MISC'],
#  ['I-MISC', 'O', 'B-MISC', 'I-PROD'],
#  ['B-PER', 'B-PROD', 'O', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'I-LOC'],
#  ['I-ORG', 'B-LOC', 'B-LOC', 'I-ORG'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-ORG', 'O', 'I-LOC', 'B-LOC'],
#  ['B-DATE', 'I-DATE', 'O', 'I-PER', 'I-MISC'],
#  ['I-PROD', 'I-PER', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-DATE'],
#  ['I-PROD', 'O', 'B-MISC', 'B-LOC', 'I-PROD'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-PER', 'O', 'O', 'I-MISC', 'B-MISC'],
#  ['B-PER', 'I-PROD', 'O', 'O'],
#  ['B-PER', 'I-MISC', 'O', 'B-PER'],
#  ['B-LOC', 'I-DATE', 'B-PER', 'I-PER'],
#  ['B-LOC', 'O', 'O', 'O', 'I-LOC'],
#  ['I-LOC', 'O', 'O', 'B-LOC', 'B-MISC'],
#  ['O', 'I-ORG', 'I-LOC', 'B-LOC', 'I-MISC'],
#  ['B-PER', 'O', 'B-DATE', 'B-ORG'],
#  ['B-PER', 'O', 'B-LOC', 'B-LOC'],
#  ['I-PER', 'O', 'I-ORG', 'I-PER'],
#  ['O', 'I-LOC', 'O', 'B-ORG'],
#  ['I-ORG', 'O', 'I-LOC', 'I-MISC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'B-MISC', 'B-LOC', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-PER'],
#  ['B-PER', 'B-PROD', 'B-PER', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC', 'I-DATE'],
#  ['B-PER', 'B-DATE', 'O', 'I-PROD'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'I-ORG', 'B-PROD'],
#  ['B-LOC', 'O', 'O', 'B-MISC'],
#  ['B-MISC', 'B-MISC', 'B-PER', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-LOC', 'I-MISC'],
#  ['I-DATE', 'I-MISC', 'O', 'B-PROD'],
#  ['I-PER', 'I-LOC', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-ORG'],
#  ['B-PER', 'B-LOC', 'O', 'B-LOC'],
#  ['B-LOC', 'O', 'B-PROD', 'B-PROD'],
#  ['B-LOC', 'O', 'O', 'B-LOC'],
#  ['B-PROD', 'I-PROD', 'O', 'B-LOC', 'B-MISC'],
#  ['B-PER', 'O', 'B-PROD', 'O'],
#  ['B-DATE', 'B-DATE', 'I-PROD', 'B-LOC'],
#  ['B-PER', 'O', 'B-ORG', 'B-DATE'],
#  ['B-PER', 'I-PROD', 'B-DATE', 'B-LOC'],
#  ['B-PER', 'B-ORG', 'O', 'B-LOC'],
#  ['I-DATE', 'O', 'I-ORG', 'B-LOC'],
#  ['I-MISC', 'I-PROD', 'B-LOC', 'B-LOC'],
#  ['I-DATE', 'O', 'B-ORG', 'B-LOC', 'I-LOC'],
#  ['I-LOC', 'O', 'B-ORG', 'I-PER'],
#  ['B-DATE', 'O', 'B-LOC', 'B-LOC'],
#  ['I-MISC', 'O', 'O', 'B-LOC'],
#  ['B-LOC', 'B-DATE', 'O', 'I-MISC'],
#  ['I-ORG', 'I-ORG', 'I-ORG', 'B-LOC'],
#  ['B-PER', 'B-PER', 'I-MISC', 'B-ORG'],
#  ['B-PER', 'B-LOC', 'O', 'B-PER'],
#  ['B-LOC', 'I-PER', 'B-LOC', 'B-MISC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-LOC', 'O', 'B-MISC'],
#  ['B-ORG', 'B-MISC', 'O', 'B-LOC'],
#  ['I-PROD', 'I-ORG', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-MISC', 'I-MISC'],
#  ['B-PER', 'O', 'I-PER', 'B-LOC'],
#  ['B-DATE', 'B-PER', 'I-PER', 'I-MISC'],
#  ['B-PER', 'O', 'O', 'B-ORG'],
#  ['B-ORG', 'I-PROD', 'I-LOC', 'B-LOC'],
#  ['B-ORG', 'B-LOC', 'B-PROD', 'I-ORG'],
#  ['B-PER', 'B-DATE', 'B-PROD', 'B-PROD'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-DATE', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-DATE', 'B-LOC', 'O'],
#  ['O', 'O', 'O', 'O', 'I-PER'],
#  ['B-LOC', 'O', 'O', 'I-DATE'],
#  ['B-PER', 'B-PROD', 'B-MISC', 'I-PER'],
#  ['B-PER', 'O', 'B-PER', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-DATE', 'O', 'B-LOC'],
#  ['B-MISC', 'I-LOC', 'O', 'I-MISC'],
#  ['I-LOC', 'I-MISC', 'B-MISC', 'O'],
#  ['B-MISC', 'O', 'O', 'I-DATE'],
#  ['B-DATE', 'O', 'I-PER', 'B-DATE'],
#  ['B-PROD', 'O', 'I-PER', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['I-PROD', 'B-MISC', 'O', 'B-LOC'],
#  ['B-PER', 'I-MISC', 'O', 'B-LOC'],
#  ['I-DATE', 'B-LOC', 'O', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'I-MISC'],
#  ['B-MISC', 'B-PER', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-DATE', 'B-LOC'],
#  ['I-LOC', 'O', 'O', 'B-LOC'],
#  ['I-ORG', 'O', 'I-PROD', 'B-LOC'],
#  ['B-PER', 'B-PER', 'I-MISC', 'I-PER', 'I-DATE'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-ORG', 'I-LOC', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-MISC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'I-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-ORG', 'O', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'I-MISC', 'B-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PROD', 'B-MISC', 'O', 'I-DATE', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-PROD'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'I-PER', 'B-LOC'],
#  ['I-LOC', 'O', 'I-LOC', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-MISC', 'I-ORG'],
#  ['I-DATE', 'O', 'O', 'B-LOC'],
#  ['I-DATE', 'O', 'O', 'B-LOC'],
#  ['B-ORG', 'B-PER', 'O', 'I-MISC'],
#  ['B-PER', 'O', 'I-ORG', 'O'],
#  ['I-LOC', 'B-PROD', 'I-PER', 'I-PER'],
#  ['B-PER', 'O', 'O', 'I-PROD'],
#  ['B-PER', 'I-MISC', 'O', 'B-PROD'],
#  ['B-PER', 'I-MISC', 'O', 'B-LOC'],
#  ['I-PROD', 'I-LOC', 'B-DATE', 'B-ORG'],
#  ['I-MISC', 'B-PER', 'I-DATE', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-LOC', 'O', 'O', 'B-LOC', 'I-LOC'],
#  ['B-LOC', 'O', 'O', 'B-LOC'],
#  ['I-LOC', 'O', 'B-MISC', 'B-LOC'],
#  ['B-PER', 'I-PER', 'I-LOC', 'B-LOC'],
#  ['B-DATE', 'O', 'O', 'B-DATE'],
#  ['B-ORG', 'B-MISC', 'B-PER', 'B-LOC', 'B-DATE'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O'],
#  ['B-PER', 'I-ORG', 'B-PER', 'O'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PROD', 'I-PER', 'I-PER', 'B-DATE'],
#  ['B-ORG', 'B-PROD', 'B-ORG', 'B-LOC'],
#  ['B-PER', 'B-ORG', 'B-LOC', 'I-MISC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['O', 'B-MISC', 'I-PER', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC', 'B-LOC'],
#  ['B-PER', 'I-LOC', 'O', 'B-LOC'],
#  ['B-PER', 'I-ORG', 'O', 'B-MISC', 'B-ORG'],
#  ['B-PER', 'I-DATE', 'B-ORG', 'I-PER'],
#  ['O', 'B-PER', 'B-MISC', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'O', 'B-LOC'],
#  ['O', 'I-LOC', 'I-DATE', 'I-MISC'],
#  ['I-PROD', 'I-PROD', 'O', 'B-PROD'],
#  ['B-PER', 'O', 'O', 'I-MISC', 'B-LOC'],
#  ['B-PER', 'I-LOC', 'I-LOC', 'I-MISC'],
#  ['B-PER', 'I-DATE', 'O', 'B-LOC'],
#  ['I-PROD', 'O', 'O', 'O', 'B-MISC'],
#  ['I-DATE', 'B-PROD', 'I-DATE', 'I-ORG'],
#  ['B-PER', 'B-MISC', 'B-DATE', 'B-LOC'],
#  ['B-PER', 'B-LOC', 'I-PROD', 'O'],
#  ['B-PER', 'I-ORG', 'O', 'B-PER'],
#  ['B-PROD', 'O', 'O', 'B-LOC', 'B-ORG'],
#  ['B-PER', 'O', 'I-ORG', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC', 'I-LOC'],
#  ['I-DATE', 'I-DATE', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'B-PROD', 'B-LOC'],
#  ['B-PER', 'B-LOC', 'O', 'B-LOC'],
#  ['B-ORG', 'B-LOC', 'B-DATE', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'I-PROD'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'I-ORG'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'I-DATE', 'B-LOC'],
#  ['I-PROD', 'O', 'O', 'O', 'I-PROD'],
#  ['I-DATE', 'B-PROD', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'I-PER', 'B-PROD'],
#  ['I-ORG', 'I-DATE', 'O', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'O', 'B-DATE', 'B-PER'],
#  ['B-PER', 'I-MISC', 'I-PER', 'B-LOC', 'I-ORG'],
#  ['O', 'I-PER', 'B-LOC', 'O'],
#  ['B-PER', 'I-MISC', 'O', 'B-LOC'],
#  ['B-MISC', 'I-MISC', 'B-PROD', 'I-PROD'],
#  ['B-DATE', 'O', 'O', 'B-LOC'],
#  ['I-LOC', 'O', 'B-DATE', 'B-LOC'],
#  ['B-ORG', 'O', 'O', 'B-ORG'],
#  ['I-PER', 'B-LOC', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-PROD'],
#  ['B-PER', 'B-ORG', 'B-ORG', 'I-DATE'],
#  ['B-PROD', 'B-DATE', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-MISC'],
#  ['B-LOC', 'B-PER', 'B-LOC', 'B-LOC'],
#  ['B-PER', 'B-ORG', 'B-PROD', 'B-PER'],
#  ['B-PER', 'O', 'O', 'I-PER'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PROD', 'B-MISC', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-ORG', 'I-DATE', 'I-PROD', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-PROD', 'O', 'B-LOC'],
#  ['B-PER', 'I-LOC', 'O', 'O'],
#  ['B-PER', 'O', 'O', 'B-PER'],
#  ['I-MISC', 'B-PROD', 'B-PER', 'I-MISC'],
#  ['B-PER', 'I-PER', 'O', 'I-MISC'],
#  ['B-PER', 'O', 'B-DATE', 'I-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-PROD'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-MISC', 'I-PER', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['I-PROD', 'O', 'I-PROD', 'O'],
#  ['B-LOC', 'O', 'I-DATE', 'B-DATE', 'I-ORG'],
#  ['B-PER', 'I-PER', 'I-DATE', 'B-LOC'],
#  ['B-PER', 'B-DATE', 'I-DATE', 'B-LOC'],
#  ['B-MISC', 'O', 'I-PER', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'B-LOC', 'I-ORG'],
#  ['B-DATE', 'O', 'I-PER', 'B-LOC'],
#  ['I-LOC', 'B-PER', 'B-LOC', 'B-LOC'],
#  ['I-PER', 'B-ORG', 'B-PROD', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-PROD', 'O', 'B-LOC'],
#  ['B-PROD', 'O', 'I-PROD', 'B-DATE'],
#  ['I-ORG', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'B-MISC', 'B-PER'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PROD', 'O', 'O', 'O'],
#  ['B-PER', 'O', 'I-PROD', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-DATE'],
#  ['B-MISC', 'I-DATE', 'O', 'I-PROD'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-MISC'],
#  ['I-MISC', 'O', 'O', 'B-PER'],
#  ['B-PER', 'B-DATE', 'O', 'O'],
#  ['B-PER', 'B-DATE', 'O', 'B-LOC'],
#  ['I-PROD', 'B-PER', 'O', 'B-LOC', 'I-ORG'],
#  ['B-PROD', 'B-DATE', 'B-MISC', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['I-DATE', 'O', 'I-LOC', 'B-MISC'],
#  ['B-PER', 'I-DATE', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-PROD'],
#  ['B-PER', 'I-DATE', 'O', 'B-LOC'],
#  ['I-ORG', 'I-LOC', 'O', 'I-DATE'],
#  ['B-MISC', 'O', 'B-LOC', 'B-LOC'],
#  ['B-PER', 'O', 'I-PER', 'I-ORG'],
#  ['B-PER', 'O', 'O', 'O', 'I-ORG'],
#  ['B-PROD', 'I-ORG', 'O', 'I-ORG'],
#  ['B-PER', 'I-MISC', 'O', 'B-LOC'],
#  ['B-LOC', 'B-PER', 'I-PROD', 'B-LOC'],
#  ['O', 'B-MISC', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-MISC', 'B-MISC'],
#  ['B-LOC', 'B-PROD', 'B-LOC', 'I-DATE', 'I-LOC'],
#  ['B-MISC', 'O', 'O', 'B-LOC'],
#  ['I-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'I-PER', 'I-DATE', 'B-LOC'],
#  ['I-DATE', 'O', 'O', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'B-DATE', 'B-MISC', 'B-LOC', 'I-LOC'],
#  ['B-DATE', 'O', 'O', 'O'],
#  ['B-ORG', 'B-MISC', 'I-LOC', 'B-LOC', 'I-LOC'],
#  ['B-PER', 'I-PER', 'O', 'B-PROD'],
#  ['B-PER', 'O', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'B-MISC', 'O', 'I-PER'],
#  ['I-PER', 'O', 'O', 'B-LOC', 'B-ORG'],
#  ['B-PER', 'O', 'O', 'I-MISC'],
#  ['B-MISC', 'B-PER', 'B-ORG', 'B-LOC'],
#  ['B-PER', 'B-LOC', 'B-PER', 'B-PROD'],
#  ['I-MISC', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-MISC', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'B-PER', 'I-MISC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'I-ORG'],
#  ['B-PER', 'O', 'B-DATE', 'B-LOC'],
#  ['B-MISC', 'B-ORG', 'O', 'B-LOC'],
#  ['B-LOC', 'O', 'O', 'B-LOC'],
#  ['B-DATE', 'O', 'O', 'I-MISC', 'I-LOC'],
#  ['I-MISC', 'I-DATE', 'O', 'B-DATE'],
#  ['B-PROD', 'B-PER', 'O', 'B-LOC'],
#  ['B-PER', 'B-PER', 'O', 'I-ORG'],
#  ['B-LOC', 'O', 'O', 'B-LOC', 'I-LOC'],
#  ['I-MISC', 'B-PROD', 'O', 'B-LOC'],
#  ['B-PER', 'O', 'O', 'B-LOC', 'I-LOC'],
#  ...]

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from torch.nn.utils.rnn import pad_sequence
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score, classification_report

# Añadir token especial <PAD> para rellenado
retrofitted_embeddings["<PAD>"] = np.zeros(100)

# Crear diccionarios de palabras y etiquetas
word_to_ix = {word: i for i, word in enumerate(retrofitted_embeddings.keys())}
tag_to_ix = {
    "O": 0,
    "B-PER": 1,
    "I-PER": 2,
    "B-ORG": 3,
    "I-ORG": 4,
    "B-LOC": 5,
    "I-LOC": 6,
    "B-MISC": 7,
    "I-MISC": 8,
    "B-PROD": 9,
    "I-PROD": 10,
}
# Añadir índice para el padding de etiquetas
pad_tag_idx = len(tag_to_ix)
tag_to_ix["<PAD>"] = pad_tag_idx

ix_to_tag = {v: k for k, v in tag_to_ix.items()}

# Tokenizar las oraciones en listas de palabras
sentences = [sentence.split() for sentence in dataNER["Sentence"].tolist()]
tags = dataNER["Tags"].tolist()

# Verificar que cada oración y su conjunto de etiquetas tengan la misma longitud
for i in range(len(sentences)):
    if len(sentences[i]) != len(tags[i]):
        print(f"Advertencia: La oración y las etiquetas en el índice {i} no coinciden en longitud.")
        print(f"Oración: {sentences[i]}")
        print(f"Etiquetas: {tags[i]}")

# Dividir datos en entrenamiento y validación
train_sentences, val_sentences, train_tags, val_tags = train_test_split(
    sentences, tags, test_size=0.2, random_state=42
)

# Dataset personalizado
class NERDataset(Dataset):
    def __init__(self, sentences, tags, word_to_ix, tag_to_ix):
        self.sentences = [[word_to_ix.get(word.lower(), word_to_ix["<PAD>"]) for word in sentence] for sentence in sentences]
        self.tags = [[tag_to_ix.get(tag, pad_tag_idx) for tag in tag_list] for tag_list in tags]

    def __len__(self):
        return len(self.sentences)

    def __getitem__(self, idx):
        return (
            torch.tensor(self.sentences[idx], dtype=torch.long),
            torch.tensor(self.tags[idx], dtype=torch.long)
        )

# Rellenado dinámico
def collate_fn(batch):
    sentences, tags = zip(*batch)
    sentences_padded = pad_sequence(sentences, batch_first=True, padding_value=word_to_ix["<PAD>"])
    tags_padded = pad_sequence(tags, batch_first=True, padding_value=pad_tag_idx)
    return sentences_padded, tags_padded

# Crear datasets y DataLoaders
train_dataset = NERDataset(train_sentences, train_tags, word_to_ix, tag_to_ix)
val_dataset = NERDataset(val_sentences, val_tags, word_to_ix, tag_to_ix)

train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=2, shuffle=False, collate_fn=collate_fn)

# Definición del modelo
class NERModel(nn.Module):
    def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size, pretrained_embeddings):
        super(NERModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.embedding.weight.data.copy_(torch.tensor(pretrained_embeddings))
        self.embedding.weight.requires_grad = False  # Congelar embeddings

        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.hidden2tag = nn.Linear(hidden_dim, tagset_size)

    def forward(self, sentences):
        embeds = self.embedding(sentences)
        lstm_out, _ = self.lstm(embeds)
        tag_space = self.hidden2tag(lstm_out)
        tag_scores = tag_space  # Sin softmax para CrossEntropyLoss
        return tag_scores

# Cargar embeddings preentrenados como tensor
pretrained_embeddings = np.array([retrofitted_embeddings[word] for word in word_to_ix.keys()])

# Inicializar modelo, pérdida y optimizador
embedding_dim = 100  # Dimensión de los embeddings
hidden_dim = 128
vocab_size = len(word_to_ix)
tagset_size = len(tag_to_ix)

model = NERModel(embedding_dim, hidden_dim, vocab_size, tagset_size, pretrained_embeddings)
loss_function = nn.CrossEntropyLoss(ignore_index=pad_tag_idx)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# Función para calcular métricas de rendimiento
def calculate_metrics(predictions, labels):
    # Convertir tensores a numpy arrays
    predictions = predictions.cpu().numpy()
    labels = labels.cpu().numpy()

    # Obtener las etiquetas únicas presentes en los datos
    unique_labels = np.unique(labels)
    labels_list = unique_labels.tolist()

    # Obtener los nombres de las etiquetas correspondientes
    target_names = [ix_to_tag[i] for i in labels_list]

    accuracy = accuracy_score(labels, predictions)
    f1 = f1_score(labels, predictions, average='macro')
    report = classification_report(labels, predictions, labels=labels_list, target_names=target_names, zero_division=0)
    return accuracy, f1, report

# Función de entrenamiento
def train_model(model, train_loader, val_loader, loss_function, optimizer, epochs=200):
    for epoch in range(epochs):
        model.train()
        total_train_loss = 0
        for sentences, tags in train_loader:
            optimizer.zero_grad()
            tag_scores = model(sentences)

            # Aplanar las dimensiones para calcular la pérdida
            loss = loss_function(tag_scores.view(-1, tagset_size), tags.view(-1))

            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()

        avg_train_loss = total_train_loss / len(train_loader)

        # Evaluación en el conjunto de validación
        model.eval()
        total_val_loss = 0
        all_predictions = []
        all_labels = []
        with torch.no_grad():
            for sentences, tags in val_loader:
                tag_scores = model(sentences)
                loss = loss_function(tag_scores.view(-1, tagset_size), tags.view(-1))
                total_val_loss += loss.item()

                predictions = torch.argmax(tag_scores, dim=2)

                # Aplicar máscara para ignorar posiciones de padding
                mask = tags != pad_tag_idx

                # Aplicar máscara y aplanar
                masked_predictions = predictions[mask]
                masked_labels = tags[mask]

                all_predictions.append(masked_predictions)
                all_labels.append(masked_labels)

        avg_val_loss = total_val_loss / len(val_loader)

        # Concatena todas las predicciones y etiquetas
        all_predictions = torch.cat(all_predictions)
        all_labels = torch.cat(all_labels)

        # Calcula métricas
        accuracy, f1, report = calculate_metrics(all_predictions, all_labels)

        print(f"Época {epoch + 1}/{epochs}")
        print(f"Pérdida de entrenamiento: {avg_train_loss:.4f}")
        print(f"Pérdida de validación: {avg_val_loss:.4f}")
        print(f"Precisión: {accuracy:.4f}")
        print(f"F1-Score: {f1:.4f}")
        print("Reporte de clasificación:")
        print(report)
        print("-" * 50)

# Entrenamiento del modelo
train_model(model, train_loader, val_loader, loss_function, optimizer, epochs=10)

# Función para evaluar una oración de prueba
def evaluate_model(model, sentence, word_to_ix, ix_to_tag):
    model.eval()
    with torch.no_grad():
        inputs = torch.tensor([word_to_ix.get(word.lower(), word_to_ix["<PAD>"]) for word in sentence], dtype=torch.long).unsqueeze(0)
        tag_scores = model(inputs)
        predicted_tags = torch.argmax(tag_scores, dim=2).squeeze().tolist()
        # Mapea los índices predichos a etiquetas
        if isinstance(predicted_tags, int):  # Si solo hay un elemento
            predicted_tags = [ix_to_tag.get(predicted_tags, "<PAD>")]
        else:
            predicted_tags = [ix_to_tag.get(tag, "<PAD>") for tag in predicted_tags]
        return predicted_tags

test_sentence = ["maria", "visits", "new", "york"]
print("Oración de prueba:", test_sentence)
print("Etiquetas predichas:", evaluate_model(model, test_sentence, word_to_ix, ix_to_tag))
# Out:
# Época 1/10
# Pérdida de entrenamiento: 1.5737
# Pérdida de validación: 1.5705
# Precisión: 0.6027
# F1-Score: 0.2250
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            O       0.64      0.90      0.75      2670
#        B-PER       0.62      0.82      0.71      1401
#        I-PER       0.00      0.00      0.00       276
#        B-ORG       0.00      0.00      0.00       294
#        I-ORG       0.00      0.00      0.00       281
#        B-LOC       0.55      0.75      0.64      1363
#        I-LOC       0.38      0.39      0.38       411
#       B-MISC       0.00      0.00      0.00       285
#       I-MISC       0.00      0.00      0.00       302
#       B-PROD       0.00      0.00      0.00       259
#       I-PROD       0.00      0.00      0.00       306
#
#     accuracy                           0.60      7848
#    macro avg       0.20      0.26      0.23      7848
# weighted avg       0.45      0.60      0.51      7848
#
# --------------------------------------------------
# Época 2/10
# Pérdida de entrenamiento: 1.5550
# Pérdida de validación: 1.5688
# Precisión: 0.6010
# F1-Score: 0.1979
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            O       0.64      0.90      0.75      2670
#        B-PER       0.62      0.82      0.71      1401
#        I-PER       0.00      0.00      0.00       276
#        B-ORG       0.00      0.00      0.00       294
#        I-ORG       0.00      0.00      0.00       281
#        B-LOC       0.51      0.84      0.64      1363
#        I-LOC       0.72      0.04      0.08       411
#       B-MISC       0.00      0.00      0.00       285
#       I-MISC       0.00      0.00      0.00       302
#       B-PROD       0.00      0.00      0.00       259
#       I-PROD       0.00      0.00      0.00       306
#
#     accuracy                           0.60      7848
#    macro avg       0.23      0.24      0.20      7848
# weighted avg       0.46      0.60      0.50      7848
#
# --------------------------------------------------
# Época 3/10
# Pérdida de entrenamiento: 1.5546
# Pérdida de validación: 1.5623
# Precisión: 0.6027
# F1-Score: 0.2250
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            O       0.64      0.90      0.75      2670
#        B-PER       0.62      0.82      0.71      1401
#        I-PER       0.00      0.00      0.00       276
#        B-ORG       0.00      0.00      0.00       294
#        I-ORG       0.00      0.00      0.00       281
#        B-LOC       0.55      0.75      0.64      1363
#        I-LOC       0.38      0.39      0.38       411
#       B-MISC       0.00      0.00      0.00       285
#       I-MISC       0.00      0.00      0.00       302
#       B-PROD       0.00      0.00      0.00       259
#       I-PROD       0.00      0.00      0.00       306
#
#     accuracy                           0.60      7848
#    macro avg       0.20      0.26      0.23      7848
# weighted avg       0.45      0.60      0.51      7848
#
# --------------------------------------------------
# Época 4/10
# Pérdida de entrenamiento: 1.5531
# Pérdida de validación: 1.5628
# Precisión: 0.6010
# F1-Score: 0.1979
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            O       0.64      0.90      0.75      2670
#        B-PER       0.62      0.82      0.71      1401
#        I-PER       0.00      0.00      0.00       276
#        B-ORG       0.00      0.00      0.00       294
#        I-ORG       0.00      0.00      0.00       281
#        B-LOC       0.51      0.84      0.64      1363
#        I-LOC       0.72      0.04      0.08       411
#       B-MISC       0.00      0.00      0.00       285
#       I-MISC       0.00      0.00      0.00       302
#       B-PROD       0.00      0.00      0.00       259
#       I-PROD       0.00      0.00      0.00       306
#
#     accuracy                           0.60      7848
#    macro avg       0.23      0.24      0.20      7848
# weighted avg       0.46      0.60      0.50      7848
#
# --------------------------------------------------
# Época 5/10
# Pérdida de entrenamiento: 1.5516
# Pérdida de validación: 1.5659
# Precisión: 0.6027
# F1-Score: 0.2250
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            O       0.64      0.90      0.75      2670
#        B-PER       0.62      0.82      0.71      1401
#        I-PER       0.00      0.00      0.00       276
#        B-ORG       0.00      0.00      0.00       294
#        I-ORG       0.00      0.00      0.00       281
#        B-LOC       0.55      0.75      0.64      1363
#        I-LOC       0.38      0.39      0.38       411
#       B-MISC       0.00      0.00      0.00       285
#       I-MISC       0.00      0.00      0.00       302
#       B-PROD       0.00      0.00      0.00       259
#       I-PROD       0.00      0.00      0.00       306
#
#     accuracy                           0.60      7848
#    macro avg       0.20      0.26      0.23      7848
# weighted avg       0.45      0.60      0.51      7848
#
# --------------------------------------------------
# Época 6/10
# Pérdida de entrenamiento: 1.5536
# Pérdida de validación: 1.5588
# Precisión: 0.6010
# F1-Score: 0.1979
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            O       0.64      0.90      0.75      2670
#        B-PER       0.62      0.82      0.71      1401
#        I-PER       0.00      0.00      0.00       276
#        B-ORG       0.00      0.00      0.00       294
#        I-ORG       0.00      0.00      0.00       281
#        B-LOC       0.51      0.84      0.64      1363
#        I-LOC       0.72      0.04      0.08       411
#       B-MISC       0.00      0.00      0.00       285
#       I-MISC       0.00      0.00      0.00       302
#       B-PROD       0.00      0.00      0.00       259
#       I-PROD       0.00      0.00      0.00       306
#
#     accuracy                           0.60      7848
#    macro avg       0.23      0.24      0.20      7848
# weighted avg       0.46      0.60      0.50      7848
#
# --------------------------------------------------
# Época 7/10
# Pérdida de entrenamiento: 1.5518
# Pérdida de validación: 1.5619
# Precisión: 0.6010
# F1-Score: 0.1979
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            O       0.64      0.90      0.75      2670
#        B-PER       0.62      0.82      0.71      1401
#        I-PER       0.00      0.00      0.00       276
#        B-ORG       0.00      0.00      0.00       294
#        I-ORG       0.00      0.00      0.00       281
#        B-LOC       0.51      0.84      0.64      1363
#        I-LOC       0.72      0.04      0.08       411
#       B-MISC       0.00      0.00      0.00       285
#       I-MISC       0.00      0.00      0.00       302
#       B-PROD       0.00      0.00      0.00       259
#       I-PROD       0.00      0.00      0.00       306
#
#     accuracy                           0.60      7848
#    macro avg       0.23      0.24      0.20      7848
# weighted avg       0.46      0.60      0.50      7848
#
# --------------------------------------------------
# Época 8/10
# Pérdida de entrenamiento: 1.5528
# Pérdida de validación: 1.5615
# Precisión: 0.6010
# F1-Score: 0.1979
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            O       0.64      0.90      0.75      2670
#        B-PER       0.62      0.82      0.71      1401
#        I-PER       0.00      0.00      0.00       276
#        B-ORG       0.00      0.00      0.00       294
#        I-ORG       0.00      0.00      0.00       281
#        B-LOC       0.51      0.84      0.64      1363
#        I-LOC       0.72      0.04      0.08       411
#       B-MISC       0.00      0.00      0.00       285
#       I-MISC       0.00      0.00      0.00       302
#       B-PROD       0.00      0.00      0.00       259
#       I-PROD       0.00      0.00      0.00       306
#
#     accuracy                           0.60      7848
#    macro avg       0.23      0.24      0.20      7848
# weighted avg       0.46      0.60      0.50      7848
#
# --------------------------------------------------
# Época 9/10
# Pérdida de entrenamiento: 1.5508
# Pérdida de validación: 1.5661
# Precisión: 0.6010
# F1-Score: 0.1979
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            O       0.64      0.90      0.75      2670
#        B-PER       0.62      0.82      0.71      1401
#        I-PER       0.00      0.00      0.00       276
#        B-ORG       0.00      0.00      0.00       294
#        I-ORG       0.00      0.00      0.00       281
#        B-LOC       0.51      0.84      0.64      1363
#        I-LOC       0.72      0.04      0.08       411
#       B-MISC       0.00      0.00      0.00       285
#       I-MISC       0.00      0.00      0.00       302
#       B-PROD       0.00      0.00      0.00       259
#       I-PROD       0.00      0.00      0.00       306
#
#     accuracy                           0.60      7848
#    macro avg       0.23      0.24      0.20      7848
# weighted avg       0.46      0.60      0.50      7848
#
# --------------------------------------------------
# Época 10/10
# Pérdida de entrenamiento: 1.5513
# Pérdida de validación: 1.5607
# Precisión: 0.6027
# F1-Score: 0.2250
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            O       0.64      0.90      0.75      2670
#        B-PER       0.62      0.82      0.71      1401
#        I-PER       0.00      0.00      0.00       276
#        B-ORG       0.00      0.00      0.00       294
#        I-ORG       0.00      0.00      0.00       281
#        B-LOC       0.55      0.75      0.64      1363
#        I-LOC       0.38      0.39      0.38       411
#       B-MISC       0.00      0.00      0.00       285
#       I-MISC       0.00      0.00      0.00       302
#       B-PROD       0.00      0.00      0.00       259
#       I-PROD       0.00      0.00      0.00       306
#
#     accuracy                           0.60      7848
#    macro avg       0.20      0.26      0.23      7848
# weighted avg       0.45      0.60      0.51      7848
#
# --------------------------------------------------
# Oración de prueba: ['maria', 'visits', 'new', 'york']
# Etiquetas predichas: ['B-PER', 'O', 'O', 'B-LOC']
